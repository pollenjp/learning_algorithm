# %% [markdown]
# # Excute C file <a class='tocSkip'>

# %%
import os
from pathlib import Path

# %% [markdown]
# # Setting

# %% [markdown]
# ## Path

# %%
HOME = Path(os.getcwd()).parent
dire = str(HOME)
print(os.path.exists(dire))
print(dire)
C_Path = HOME / "c"
dire = str(C_Path)
print(os.path.exists(dire))
print(dire)
data_Path = HOME / "data"
dire = str(data_Path)
print(os.path.exists(dire))
print(dire)
input_Path = data_Path / "input"
dire = str(input_Path)
print(os.path.exists(dire))
print(dire)
# Out:
# True
# /home/pollen/workdir/git/github/learning_algorithm/atcoder/arc096/D_Static_Sushi
# True
# /home/pollen/workdir/git/github/learning_algorithm/atcoder/arc096/D_Static_Sushi/c
# True
# /home/pollen/workdir/git/github/learning_algorithm/atcoder/arc096/D_Static_Sushi/data
# True
# /home/pollen/workdir/git/github/learning_algorithm/atcoder/arc096/D_Static_Sushi/data/input

# %% [markdown]
# ## Check

# %%
# !ls -l {C_Path}
# Out:
# 合計 60
# -rw-rw-r-- 1 pollen pollen   393  7月  8 10:12 Makefile
# -rwxrwxr-x 1 pollen pollen  8600  7月  8 08:15 a.out
# -rw-rw-r-- 1 pollen pollen  2415  7月  8 08:15 d_static_sushi.c
# -rwxrwxr-x 1 pollen pollen  8736  7月  8 10:16 d_static_sushi.o
# -rw-rw-r-- 1 pollen pollen  3665  7月  8 09:54 d_static_sushi__file_io.c
# -rwxrwxr-x 1 pollen pollen 13096  7月  8 09:44 d_static_sushi__file_io.o
# -rw-rw-r-- 1 pollen pollen  1990  7月  8 08:15 d_static_sushi_submit.c
# -rw-rw-r-- 1 pollen pollen   213  7月  8 08:15 try.c

# %%
# !ls -l {data_Path}
# Out:
# 合計 8
# drwxrwxr-x 2 pollen pollen 4096  7月  8 10:24 input
# drwxrwxr-x 2 pollen pollen 4096  7月  8 10:24 output

# %%
# !ls -l {input_Path}
# Out:
# 合計 16
# -rw-rw-r-- 1 pollen pollen  21  7月  8 08:15 sampleIn1
# -rw-rw-r-- 1 pollen pollen  21  7月  8 08:15 sampleIn2
# -rw-rw-r-- 1 pollen pollen  35  7月  8 08:15 sampleIn3
# -rw-rw-r-- 1 pollen pollen 343  7月  8 08:15 sampleIn4

# %% [markdown]
# # Compile

# %%
excute_file_path = str(C_Path / "d_static_sushi.out")

# %%
# !gcc {str(C_Path / "d_static_sushi.c")} -o {excute_file_path}

# %% [markdown]
# # Excute

# %% [markdown]
# ## Sampe 1

# %%
input_file = input_Path / "sampleIn1"
# !{excute_file_path} < {input_file}
# Out:
# 3 20
# 2 80
# 9 120
# 16 1
# calorie : 0
# calorie(v_1 + ... + v_a) : 0
# calorie(v_b + ... + v_n) : 80
# calorie(v_b + ... + v_n) : 200
# calorie(v_b + ... + v_n) : 201
# calorie(v_b + ... + v_n) : 201
# calorie : 183
# max_calorie : 183
# calorie : 0
# calorie(v_1 + ... + v_a) : 0
# calorie(v_b + ... + v_n) : 120
# calorie(v_b + ... + v_n) : 121
# calorie(v_b + ... + v_n) : 121
# calorie : 110
# max_calorie : 183
# calorie : 0
# calorie(v_1 + ... + v_a) : 0
# calorie(v_b + ... + v_n) : 1
# calorie(v_b + ... + v_n) : 1
# calorie : 18446744073709551613
# max_calorie : 183
# calorie : 0
# calorie(v_1 + ... + v_a) : 0
# calorie(v_b + ... + v_n) : 0
# calorie : 0
# max_calorie : 183
# calorie : 0
# calorie(v_1 + ... + v_a) : 0
# calorie(v_1 + ... + v_a) : 80
# calorie(v_b + ... + v_n) : 200
# calorie(v_b + ... + v_n) : 201
# calorie(v_b + ... + v_n) : 201
# calorie : 186
# max_calorie : 186
# calorie : 0
# calorie(v_1 + ... + v_a) : 0
# calorie(v_1 + ... + v_a) : 80
# ...

# %% [markdown]
# ## Sampe 2

# %%
input_file = input_Path / "sampleIn2"
# !{excute_file_path} < {input_file}
# Out:
# 3 20
# 2 80
# 9 1
# 16 120
# calorie : 0
# calorie(v_1 + ... + v_a) : 0
# calorie(v_b + ... + v_n) : 80
# calorie(v_b + ... + v_n) : 81
# calorie(v_b + ... + v_n) : 201
# calorie(v_b + ... + v_n) : 201
# calorie : 183
# max_calorie : 183
# calorie : 0
# calorie(v_1 + ... + v_a) : 0
# calorie(v_b + ... + v_n) : 1
# calorie(v_b + ... + v_n) : 121
# calorie(v_b + ... + v_n) : 121
# calorie : 110
# max_calorie : 183
# calorie : 0
# calorie(v_1 + ... + v_a) : 0
# calorie(v_b + ... + v_n) : 120
# calorie(v_b + ... + v_n) : 120
# calorie : 116
# max_calorie : 183
# calorie : 0
# calorie(v_1 + ... + v_a) : 0
# calorie(v_b + ... + v_n) : 0
# calorie : 0
# max_calorie : 183
# calorie : 0
# calorie(v_1 + ... + v_a) : 0
# calorie(v_1 + ... + v_a) : 80
# calorie(v_b + ... + v_n) : 81
# calorie(v_b + ... + v_n) : 201
# calorie(v_b + ... + v_n) : 201
# calorie : 186
# max_calorie : 186
# calorie : 0
# calorie(v_1 + ... + v_a) : 0
# calorie(v_1 + ... + v_a) : 80
# calorie(v_b + ... + v_n) : 200
# ...

# %% [markdown]
# ## Sampe 3

# %%
input_file = input_Path / "sampleIn3"
# !{excute_file_path} < {input_file}
# Out:
# 1 100000000000000
# 50000000000000 1
# calorie : 0
# calorie(v_1 + ... + v_a) : 0
# calorie(v_b + ... + v_n) : 1
# calorie(v_b + ... + v_n) : 1
# calorie : 18446694073709551617
# max_calorie : 0
# calorie : 0
# calorie(v_1 + ... + v_a) : 0
# calorie(v_b + ... + v_n) : 0
# calorie : 0
# max_calorie : 0
# calorie : 0
# calorie(v_1 + ... + v_a) : 0
# calorie(v_1 + ... + v_a) : 1
# calorie(v_b + ... + v_n) : 1
# calorie : 18446694073709551617
# max_calorie : 0
# max_calorie : 0
# init_calorie : 0
# 0

# %% [markdown]
# ## Sampe 4

# %%
input_file = input_Path / "sampleIn4"
# !{excute_file_path} < {input_file}
# Out:
# 15 10000000000
# 400000000 1000000000
# 800000000 1000000000
# 1900000000 1000000000
# 2400000000 1000000000
# 2900000000 1000000000
# 3300000000 1000000000
# 3700000000 1000000000
# 3800000000 1000000000
# 4000000000 1000000000
# 4100000000 1000000000
# 5200000000 1000000000
# 6600000000 1000000000
# 8000000000 1000000000
# 9300000000 1000000000
# 9700000000 1000000000
# calorie : 0
# calorie(v_1 + ... + v_a) : 0
# calorie(v_b + ... + v_n) : 1000000000
# calorie(v_b + ... + v_n) : 2000000000
# calorie(v_b + ... + v_n) : 3000000000
# calorie(v_b + ... + v_n) : 4000000000
# calorie(v_b + ... + v_n) : 5000000000
# calorie(v_b + ... + v_n) : 6000000000
# calorie(v_b + ... + v_n) : 7000000000
# calorie(v_b + ... + v_n) : 8000000000
# calorie(v_b + ... + v_n) : 9000000000
# calorie(v_b + ... + v_n) : 10000000000
# calorie(v_b + ... + v_n) : 11000000000
# calorie(v_b + ... + v_n) : 12000000000
# calorie(v_b + ... + v_n) : 13000000000
# calorie(v_b + ... + v_n) : 14000000000
# ...
